# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def show_comparision(original, blur3, blur5, blur7, blur11, blur15):
  plt.figure(figsize=(15, 10))

  plt.subplot(2, 3, 1)
  plt.imshow(original, cmap='gray')
  plt.title("Original Image")
  plt.axis('off')

  plt.subplot(2, 3, 2)
  plt.imshow(blur3, cmap='gray')
  plt.title("3x3 Average Filter")
  plt.axis('off')

  plt.subplot(2, 3, 3)
  plt.imshow(blur5, cmap='gray')
  plt.title("5x5 Average Filter")
  plt.axis('off')

  plt.subplot(2, 3, 4)
  plt.imshow(blur7, cmap='gray')
  plt.title("7x7 Average Filter")
  plt.axis('off')

  plt.subplot(2, 3, 5)
  plt.imshow(blur11, cmap='gray')
  plt.title("11x11 Average Filter")
  plt.axis('off')

  plt.subplot(2, 3, 6)
  plt.imshow(blur15, cmap='gray')
  plt.title("15x15 Average Filter")
  plt.axis('off')

  plt.tight_layout()
  plt.show()

# %%
show_comparision(img, blur_3x3, blur_5x5, blur_7x7, blur_11x11, blur_15x15)

# %%
# Define the path to your image file
image_path = '/content/drive/MyDrive/CV/cleanimage.jpg' # <--- Please update this path if your image is located elsewhere or after uploading it.

# Define kernels - these can be defined independently of image loading
kernel_3x3 = np.ones((3,3), np.float32)/9
kernel_5x5 = np.ones((5,5), np.float32)/25
kernel_7x7 = np.ones((7,7), np.float32)/49
kernel_11x11 = np.ones((11,11), np.float32)/121
kernel_15x15 = np.ones((15,15), np.float32)/225

img = cv2.imread(image_path, 0) # Attempt to load the image in grayscale

if img is None:
  print(f"Error: Could not load image from '{image_path}'.")
  print("Please ensure the image file exists and the path is correct.")
  print("If you need to upload the image, use the file browser icon on the left panel (Files > Upload to session storage).")
else:
  print(f"Image '{image_path}' loaded successfully. Image shape: {img.shape}")
# Out:
# Image '/content/drive/MyDrive/CV/cleanimage.jpg' loaded successfully. Image shape: (447, 447)

# %%
blur_3x3=cv2.filter2D(img,-1,kernel_3x3)
blur_5x5=cv2.filter2D(img,-1,kernel_5x5)
blur_7x7=cv2.filter2D(img,-1,kernel_7x7)
blur_11x11=cv2.filter2D(img,-1,kernel_11x11)
blur_15x15=cv2.filter2D(img,-1,kernel_15x15)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/drive/MyDrive/CV/clean image.jfif", 0)

# %%
K = 3
kernel = np.ones((K, K)) / 9

# %%
P = K // 2

# %%
padded = np.pad(img, ((P, P), (P, P)), mode='constant')

# %%
filtered = np.zeros_like(img, dtype=float)

# %%
for i in range(img.shape[0]):
    for j in range(img.shape[1]):

        region = padded[i:i+K, j:j+K]

        filtered[i, j] = np.sum(region * kernel)

# %%
filtered = np.uint8(filtered)

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(filtered, cmap='gray')
plt.title("Filtered Image")
plt.axis("off")

plt.show()
